# %%
import pandas as pd
import matplotlib as mtl

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')

# %%
df[df['Country/Region'] == 'India']
# Out:
#     Province/State Country/Region        Lat      Long  1/22/20  1/23/20  \
# 147            NaN          India  20.593684  78.96288        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  11/24/21  11/25/21  11/26/21  \
# 147        0        0        0        0  ...  34544882  34555431  34563749
#
#      11/27/21  11/28/21  11/29/21  11/30/21   12/1/21   12/2/21   12/3/21
# 147  34572523  34580832  34587822  34596776  34606541  34615757  34624360
#
# [1 rows x 686 columns]

# %%
#trasposed_df = df.melt(id_vars=['Country/Region', 'Province/State', 'Lat', 'Long'] ,var_name= 'Date', value_name='Cases')

# %%
df_india = df.melt(id_vars=['Country/Region', 'Province/State', 'Lat', 'Long'] ,var_name= 'Date', value_name='Cases')
#removing unwanted rows
df_india.drop(columns=['Province/State','Lat','Long'], inplace=True)
df_india = df_india[df_india['Country/Region'] == 'India']
df_india
# Out:
#        Country/Region      Date     Cases
# 147             India   1/22/20         0
# 427             India   1/23/20         0
# 707             India   1/24/20         0
# 987             India   1/25/20         0
# 1267            India   1/26/20         0
# ...               ...       ...       ...
# 189707          India  11/29/21  34587822
# 189987          India  11/30/21  34596776
# 190267          India   12/1/21  34606541
# 190547          India   12/2/21  34615757
# 190827          India   12/3/21  34624360
#
# [682 rows x 3 columns]

# %%
trasposed_df[trasposed_df['Country/Region'] == 'India']
# Out:
#        Country/Region Province/State        Lat      Long      Date     Cases
# 147             India            NaN  20.593684  78.96288   1/22/20         0
# 427             India            NaN  20.593684  78.96288   1/23/20         0
# 707             India            NaN  20.593684  78.96288   1/24/20         0
# 987             India            NaN  20.593684  78.96288   1/25/20         0
# 1267            India            NaN  20.593684  78.96288   1/26/20         0
# ...               ...            ...        ...       ...       ...       ...
# 189707          India            NaN  20.593684  78.96288  11/29/21  34587822
# 189987          India            NaN  20.593684  78.96288  11/30/21  34596776
# 190267          India            NaN  20.593684  78.96288   12/1/21  34606541
# 190547          India            NaN  20.593684  78.96288   12/2/21  34615757
# 190827          India            NaN  20.593684  78.96288   12/3/21  34624360
#
# [682 rows x 6 columns]

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

# %%
fig = px.line(data_frame=df_india,x = 'Date', y='Cases')

# %%
fig
# Out:
# <div>                            <div id="3e8cf91a-1e9b-4b7b-b1d6-a47c0b0f3d74" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e8cf91a-1e9b-4b7b-b1d6-a47c0b0f3d74")) {                    Plotly.newPlot(                        "3e8cf91a-1e9b-4b7b-b1d6-a47c0b0f3d74",                        [{"hovertemplate":"Date=%{x}<br>Cases=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1/22/20","1/23/20","1/24/20","1/25/20","1/26/20","1/27/20","1/28/20","1/29/20","1/30/20","1/31/20","2/1/20","2/2/20","2/3/20","2/4/20","2/5/20","2/6/20","2/7/20","2/8/20","2/9/20","2/10/20","2/11/20","2/12/20","2/13/20","2/14/20","2/15/20","2/16/20","2/
# ...
